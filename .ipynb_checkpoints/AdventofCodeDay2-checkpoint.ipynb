# %%
filepath = '/Users/liz/Documents/Advent2019/day2.txt'
opcode=[]

with open(filepath) as file:
    for line in file:
        for column in line.strip().split(','):
            opcode.append(int(column))
opcode[1] = 25
opcode[2] = 52
print(opcode)

o_operator = 0

while True:
    print('opcode address: '+ str(o_operator))
    o_value1 = o_operator + 1
    o_value2 = o_operator + 2
    o_result = o_operator + 3

    if opcode[o_operator] == 1:
        result = opcode[opcode[o_value1]] + opcode[opcode[o_value2]]
        opcode[opcode[o_result]] = result
        o_operator+=4
        print(opcode)
    elif opcode[o_operator] == 2:
        result = opcode[opcode[o_value1]] * opcode[opcode[o_value2]]
        opcode[opcode[o_result]] = result
        o_operator+=4
        print(opcode)
    elif opcode[o_operator] == 99:
        print (opcode)
        break
    else:
        print('invalid opcode')
        print(opcode)
        break
# Out:
# [1, 25, 52, 3, 1, 1, 2, 3, 1, 3, 4, 3, 1, 5, 0, 3, 2, 10, 1, 19, 1, 5, 19, 23, 1, 23, 5, 27, 2, 27, 10, 31, 1, 5, 31, 35, 2, 35, 6, 39, 1, 6, 39, 43, 2, 13, 43, 47, 2, 9, 47, 51, 1, 6, 51, 55, 1, 55, 9, 59, 2, 6, 59, 63, 1, 5, 63, 67, 2, 67, 13, 71, 1, 9, 71, 75, 1, 75, 9, 79, 2, 79, 10, 83, 1, 6, 83, 87, 1, 5, 87, 91, 1, 6, 91, 95, 1, 95, 13, 99, 1, 10, 99, 103, 2, 6, 103, 107, 1, 107, 5, 111, 1, 111, 13, 115, 1, 115, 13, 119, 1, 13, 119, 123, 2, 123, 13, 127, 1, 127, 6, 131, 1, 131, 9, 135, 1, 5, 135, 139, 2, 139, 6, 143, 2, 6, 143, 147, 1, 5, 147, 151, 1, 151, 2, 155, 1, 9, 155, 0, 99, 2, 14, 0, 0]
# opcode address: 0
# ...

# %%
filepath = '/Users/liz/Documents/Advent2019/day2.txt'
opcode1=[]

with open(filepath) as file:
    for line in file:
        for column in line.strip().split(','):
            opcode1.append(int(column))

for noun in range(100):
#    print(noun)
    for verb in range(100):
        print('noun '+ str(noun)+ ' verb '+ str(verb))
        
        opcode = []
        opcode = opcode1[:]
        opcode[1] = noun
        opcode[2] = verb
        o_operator = 0
        
        while True:
            print('opcode address: '+ str(o_operator))
            o_value1 = o_operator + 1
            o_value2 = o_operator + 2
            o_result = o_operator + 3

            if opcode[o_operator] == 1:
                result = opcode[opcode[o_value1]] + opcode[opcode[o_value2]]
                opcode[opcode[o_result]] = result
                o_operator+=4
#                print(opcode)
            elif opcode[o_operator] == 2:
                result = opcode[opcode[o_value1]] * opcode[opcode[o_value2]]
                opcode[opcode[o_result]] = result
                o_operator+=4
#                print(opcode)
            elif opcode[o_operator] == 99:
#                print (opcode)
                break
            else:
                print('invalid opcode')
#                print(opcode)
                break


        if opcode[0] == 19690720:
            print('result has been found')
            print(opcode)
            break
    if opcode[0] == 19690720:
        break
print(100*noun+verb)
# Out:
# noun 0 verb 0
# opcode address: 0
# opcode address: 4
# opcode address: 8
# opcode address: 12
# opcode address: 16
# opcode address: 20
# opcode address: 24
# opcode address: 28
# opcode address: 32
# opcode address: 36
# opcode address: 40
# opcode address: 44
# opcode address: 48
# opcode address: 52
# opcode address: 56
# opcode address: 60
# opcode address: 64
# opcode address: 68
# opcode address: 72
# opcode address: 76
# opcode address: 80
# opcode address: 84
# opcode address: 88
# opcode address: 92
# opcode address: 96
# opcode address: 100
# opcode address: 104
# opcode address: 108
# opcode address: 112
# opcode address: 116
# opcode address: 120
# opcode address: 124
# opcode address: 128
# opcode address: 132
# opcode address: 136
# opcode address: 140
# opcode address: 144
# opcode address: 148
# opcode address: 152
# opcode address: 156
# opcode address: 160
# noun 0 verb 1
# opcode address: 0
# opcode address: 4
# opcode address: 8
# opcode address: 12
# ...

# %%
for noun in range(100):
#    print(noun)
    for verb in range(100):
        print('noun '+ str(noun)+ ' verb '+ str(verb))
# Out:
# noun 0 verb 0
# noun 0 verb 1
# noun 0 verb 2
# noun 0 verb 3
# noun 0 verb 4
# noun 0 verb 5
# noun 0 verb 6
# noun 0 verb 7
# noun 0 verb 8
# noun 0 verb 9
# noun 0 verb 10
# noun 0 verb 11
# noun 0 verb 12
# noun 0 verb 13
# noun 0 verb 14
# noun 0 verb 15
# noun 0 verb 16
# noun 0 verb 17
# noun 0 verb 18
# noun 0 verb 19
# noun 0 verb 20
# noun 0 verb 21
# noun 0 verb 22
# noun 0 verb 23
# noun 0 verb 24
# noun 0 verb 25
# noun 0 verb 26
# noun 0 verb 27
# noun 0 verb 28
# noun 0 verb 29
# noun 0 verb 30
# noun 0 verb 31
# noun 0 verb 32
# noun 0 verb 33
# noun 0 verb 34
# noun 0 verb 35
# noun 0 verb 36
# noun 0 verb 37
# noun 0 verb 38
# noun 0 verb 39
# noun 0 verb 40
# noun 0 verb 41
# noun 0 verb 42
# noun 0 verb 43
# noun 0 verb 44
# noun 0 verb 45
# noun 0 verb 46
# noun 0 verb 47
# noun 0 verb 48
# noun 0 verb 49
# noun 0 verb 50
# noun 0 verb 51
# noun 0 verb 52
# noun 0 verb 53
# noun 0 verb 54
# noun 0 verb 55
# noun 0 verb 56
# noun 0 verb 57
# noun 0 verb 58
# ...
